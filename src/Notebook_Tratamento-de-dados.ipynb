# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data2004_1 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2004\\ca-2004-01.csv",on_bad_lines='skip', sep=';')
DF2004_1 = pd.DataFrame(data2004_1)
data2004_2 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2004\\ca-2004-02.csv",on_bad_lines='skip',  sep=';')
DF2004_2 = pd.DataFrame(data2004_2)

DF2004 = pd.concat([DF2004_1,DF2004_2], axis = 0)

print(DF2004)
# Out:
#        Regiao - Sigla Estado - Sigla                    Municipio  \
# 0                  SE             SP                    GUARULHOS
# 1                  SE             SP                    GUARULHOS
# 2                  SE             SP                    GUARULHOS
# 3                  SE             SP                     SOROCABA
# 4                  SE             SP                     SOROCABA
# ...               ...            ...                          ...
# 915312             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 915313             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 915314             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 915315             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 915316             NE             BA  LIVRAMENTO DE NOSSA SENHORA
#
#                                                   Revenda  \
# 0                                AUTO POSTO SAKAMOTO LTDA
# ...

# %%
data2005_1 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2005\\ca-2005-01.csv",on_bad_lines='skip', sep=';')
DF2005_1 = pd.DataFrame(data2005_1)
data2005_2 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2005\\ca-2005-02.csv",on_bad_lines='skip',  sep=';')
DF2005_2 = pd.DataFrame(data2005_2)

DF2005 = pd.concat([DF2005_1,DF2005_2], axis = 0)

print(DF2005)
# Out:
#        Regiao - Sigla Estado - Sigla                    Municipio  \
# 0                  SE             SP                    GUARULHOS
# 1                  SE             SP                    GUARULHOS
# 2                  SE             SP                    GUARULHOS
# 3                  SE             SP                     SOROCABA
# 4                  SE             SP                     SOROCABA
# ...               ...            ...                          ...
# 741808             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 741809             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 741810             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 741811             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 741812             NE             BA  LIVRAMENTO DE NOSSA SENHORA
#
#                                                   Revenda  \
# 0                                AUTO POSTO SAKAMOTO LTDA
# ...

# %%
data2006_1 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2006\\ca-2006-01.csv",on_bad_lines='skip', sep=';')
DF2006_1 = pd.DataFrame(data2006_1)
data2006_2 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2006\\ca-2006-02.csv",on_bad_lines='skip',  sep=';')
DF2006_2 = pd.DataFrame(data2006_2)

DF2006 = pd.concat([DF2006_1,DF2006_2], axis = 0)

print(DF2006)
# Out:
#        Regiao - Sigla Estado - Sigla                    Municipio  \
# 0                  SE             SP                    GUARULHOS
# 1                  SE             SP                    GUARULHOS
# 2                  SE             SP                    GUARULHOS
# 3                  SE             SP                     SOROCABA
# 4                  SE             SP                     SOROCABA
# ...               ...            ...                          ...
# 802329             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 802330             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 802331             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 802332             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 802333             NE             BA  LIVRAMENTO DE NOSSA SENHORA
#
#                                                   Revenda  \
# 0                                AUTO POSTO SAKAMOTO LTDA
# ...

# %%
data2007_1 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2007\\ca-2007-01.csv",on_bad_lines='skip', sep=';')
DF2007_1 = pd.DataFrame(data2007_1)
data2007_2 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2007\\ca-2007-02.csv",on_bad_lines='skip',  sep=';')
DF2007_2 = pd.DataFrame(data2007_2)

DF2007 = pd.concat([DF2007_1,DF2007_2], axis = 0)

print(DF2007)
# Out:
#        Regiao - Sigla Estado - Sigla                    Municipio  \
# 0                  SE             SP                     SOROCABA
# 1                  SE             SP                     SOROCABA
# 2                  SE             SP                     SOROCABA
# 3                  SE             RJ               RIO DE JANEIRO
# 4                  SE             RJ               RIO DE JANEIRO
# ...               ...            ...                          ...
# 659627             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 659628             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 659629             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 659630             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 659631             NE             BA  LIVRAMENTO DE NOSSA SENHORA
#
#                                                   Revenda  \
# 0       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# ...

# %%
data2008_1 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2008\\ca-2008-01.csv",on_bad_lines='skip', sep=';')
DF2008_1 = pd.DataFrame(data2008_1)
data2008_2 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2008\\ca-2008-02.csv",on_bad_lines='skip',  sep=';')
DF2008_2 = pd.DataFrame(data2008_2)

DF2008 = pd.concat([DF2008_1,DF2008_2], axis = 0)

print(DF2008)
# Out:
#        Regiao - Sigla Estado - Sigla                    Municipio  \
# 0                  NE             BA                      ITABUNA
# 1                  NE             BA                      ITABUNA
# 2                  NE             BA                      ITABUNA
# 3                  SE             MG     SAO SEBASTIAO DO PARAISO
# 4                  SE             MG     SAO SEBASTIAO DO PARAISO
# ...               ...            ...                          ...
# 678552             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 678553             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 678554             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 678555             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 678556             NE             BA  LIVRAMENTO DE NOSSA SENHORA
#
#                                           Revenda      CNPJ da Revenda  \
# 0       LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
# ...

# %%
data2009_1 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2009\\ca-2009-01.csv",on_bad_lines='skip', sep=';')
DF2009_1 = pd.DataFrame(data2009_1)
data2009_2 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2009\\ca-2009-02.csv",on_bad_lines='skip',  sep=';')
DF2009_2 = pd.DataFrame(data2009_2)

DF2009 = pd.concat([DF2009_1,DF2009_2], axis = 0)

print(DF2009)
# Out:
#        Regiao - Sigla Estado - Sigla                    Municipio  \
# 0                  SE             SP                       OSASCO
# 1                  SE             SP                       OSASCO
# 2                  SE             SP                       OSASCO
# 3                  SE             SP                     SOROCABA
# 4                  SE             SP                     SOROCABA
# ...               ...            ...                          ...
# 485886             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 485887             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 485888             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 485889             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 485890             NE             BA  LIVRAMENTO DE NOSSA SENHORA
#
#                                                   Revenda  \
# 0                                 AUTO POSTO ROMA II LTDA
# ...

# %%
data2010_1 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2010\\ca-2010-01.csv",on_bad_lines='skip', sep=';')
DF2010_1 = pd.DataFrame(data2010_1)
data2010_2 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2010\\ca-2010-02.csv",on_bad_lines='skip',  sep=';')
DF2010_2 = pd.DataFrame(data2010_2)

DF2010 = pd.concat([DF2010_1,DF2010_2], axis = 0)

print(DF2010)
# Out:
#        Regiao - Sigla Estado - Sigla     Municipio  \
# 0                  SE             SP     GUARULHOS
# 1                  SE             SP     GUARULHOS
# 2                  SE             SP     GUARULHOS
# 3                  SE             SP     GUARULHOS
# 4                  NE             BA       ITABUNA
# ...               ...            ...           ...
# 645334              S             RS  SAO LEOPOLDO
# 645335             SE             SP     SAO PAULO
# 645336             SE             SP     SAO PAULO
# 645337             SE             SP     SAO PAULO
# 645338             SE             SP     SAO PAULO
#
#                                           Revenda      CNPJ da Revenda  \
# 0                        AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 1                        AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 2                        AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# ...

# %%
data2011_1 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2011\\ca-2011-01.csv",on_bad_lines='skip', sep=';')
DF2011_1 = pd.DataFrame(data2011_1)
data2011_2 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2011\\ca-2011-02.csv",on_bad_lines='skip',  sep=';')
DF2011_2 = pd.DataFrame(data2011_2)

DF2011 = pd.concat([DF2011_1,DF2011_2], axis = 0)

print(DF2011)
# Out:
#        Regiao - Sigla Estado - Sigla      Municipio  \
# 0                  SE             SP     ARARAQUARA
# 1                  SE             SP     ARARAQUARA
# 2                  SE             SP     ARARAQUARA
# 3                  SE             SP      GUARULHOS
# 4                  SE             SP      GUARULHOS
# ...               ...            ...            ...
# 650003              S             RS  NOVO HAMBURGO
# 650004              S             RS  NOVO HAMBURGO
# 650005             CO             GO     PLANALTINA
# 650006             CO             GO     PLANALTINA
# 650007             CO             GO     PLANALTINA
#
#                                        Revenda      CNPJ da Revenda  \
# 0       RAIZEN ARARAQUARA ACUCAR E ALCOOL LTDA   43.960.335/0001-64
# 1       RAIZEN ARARAQUARA ACUCAR E ALCOOL LTDA   43.960.335/0001-64
# 2       RAIZEN ARARAQUARA ACUCAR E ALCOOL LTDA   43.960.335/0001-64
# ...

# %%
data2012_1 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2012\\ca-2012-01.csv",on_bad_lines='skip', sep=';')
DF2012_1 = pd.DataFrame(data2012_1)
data2012_2 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2012\\ca-2012-02.csv",on_bad_lines='skip',  sep=';')
DF2012_2 = pd.DataFrame(data2012_2)

DF2012 = pd.concat([DF2012_1,DF2012_2], axis = 0)

print(DF2012)
# Out:
#        Regiao - Sigla Estado - Sigla   Municipio  \
# 0                  SE             SP   GUARULHOS
# 1                  SE             SP   GUARULHOS
# 2                  SE             SP   GUARULHOS
# 3                  CO             DF    BRASILIA
# 4                  CO             DF    BRASILIA
# ...               ...            ...         ...
# 672252              N             TO      GURUPI
# 672253              N             TO      GURUPI
# 672254             CO             GO  PLANALTINA
# 672255             CO             GO  PLANALTINA
# 672256             CO             GO  PLANALTINA
#
#                                      Revenda      CNPJ da Revenda  \
# 0                   AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 1                   AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 2                   AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 3       GASOL COMBUSTÍVEIS AUTOMOTIVOS LTDA.   00.603.738/0001-43
# ...

# %%
data2013_1 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2013\\ca-2013-01.csv",on_bad_lines='skip', sep=';')
DF2013_1 = pd.DataFrame(data2013_1)
data2013_2 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2013\\ca-2013-02.csv",on_bad_lines='skip',  sep=';')
DF2013_2 = pd.DataFrame(data2013_2)

DF2013 = pd.concat([DF2013_1,DF2013_2], axis = 0)

print(DF2013)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  SE             SP  GUARULHOS
# 1                  SE             SP  GUARULHOS
# 2                  SE             SP  GUARULHOS
# 3                  SE             SP  GUARULHOS
# 4                  CO             DF   BRASILIA
# ...               ...            ...        ...
# 699367              N             PA   SANTAREM
# 699368              N             PA   SANTAREM
# 699369             SE             SP      BAURU
# 699370             SE             SP      BAURU
# 699371             SE             SP      BAURU
#
#                                      Revenda      CNPJ da Revenda  \
# 0                   AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 1                   AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 2                   AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 3                   AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# ...

# %%
data2014_1 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2014\\ca-2014-01.csv",on_bad_lines='skip', sep=';')
DF2014_1 = pd.DataFrame(data2014_1)
data2014_2 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2014\\ca-2014-02.csv",on_bad_lines='skip',  sep=';')
DF2014_2 = pd.DataFrame(data2014_2)

DF2014 = pd.concat([DF2014_1,DF2014_2], axis = 0)

print(DF2014)
# Out:
#        Regiao - Sigla Estado - Sigla      Municipio  \
# 0                  SE             SP      GUARULHOS
# 1                  SE             SP      GUARULHOS
# 2                  SE             SP      GUARULHOS
# 3                  SE             SP      GUARULHOS
# 4                  SE             SP      GUARULHOS
# ...               ...            ...            ...
# 723083              S             PR  FOZ DO IGUACU
# 723084              S             PR  FOZ DO IGUACU
# 723085             CO             GO     PLANALTINA
# 723086             CO             GO     PLANALTINA
# 723087             CO             GO     PLANALTINA
#
#                                      Revenda      CNPJ da Revenda  \
# 0                   AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 1                   AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 2                   AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 3                   AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# ...

# %%
data2015_1 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2015\\ca-2015-01.csv",on_bad_lines='skip', sep=';')
DF2015_1 = pd.DataFrame(data2015_1)
data2015_2 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2015\\ca-2015-02.csv",on_bad_lines='skip',  sep=';')
DF2015_2 = pd.DataFrame(data2015_2)

DF2015 = pd.concat([DF2015_1,DF2015_2], axis = 0)

print(DF2015)
# Out:
#        Regiao - Sigla Estado - Sigla         Municipio  \
# 0                   N             AC  SENADOR GUIOMARD
# 1                   N             AC  SENADOR GUIOMARD
# 2                   N             AC  SENADOR GUIOMARD
# 3                   N             AC  SENADOR GUIOMARD
# 4                   N             AC  SENADOR GUIOMARD
# ...               ...            ...               ...
# 410969             SE             MG       SETE LAGOAS
# 410970             SE             MG       SETE LAGOAS
# 410971              N             AC        RIO BRANCO
# 410972              N             AC        RIO BRANCO
# 410973              N             AC        RIO BRANCO
#
#                             Revenda      CNPJ da Revenda  \
# 0       AUTO POSTO SANTA RITA LTDA.   07.600.665/0001-85
# 1       AUTO POSTO SANTA RITA LTDA.   07.600.665/0001-85
# 2       AUTO POSTO SANTA RITA LTDA.   07.600.665/0001-85
# 3       AUTO POSTO SANTA RITA LTDA.   07.600.665/0001-85
# ...

# %%
data2016_1 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2016\\ca-2016-01.csv",on_bad_lines='skip', sep=';')
DF2016_1 = pd.DataFrame(data2016_1)
data2016_2 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2016\\ca-2016-02.csv",on_bad_lines='skip',  sep=';')
DF2016_2 = pd.DataFrame(data2016_2)

DF2016 = pd.concat([DF2016_1,DF2016_2], axis = 0)

print(DF2016)
# Out:
#        Regiao - Sigla Estado - Sigla      Municipio  \
# 0                  SE             SP       SOROCABA
# 1                  SE             SP       SOROCABA
# 2                  SE             SP       SOROCABA
# 3                  NE             BA        ITABUNA
# 4                  NE             BA        ITABUNA
# ...               ...            ...            ...
# 488955             CO             GO      ITUMBIARA
# 488956             CO             GO      ITUMBIARA
# 488957             CO             MT  VARZEA GRANDE
# 488958             CO             MT  VARZEA GRANDE
# 488959             CO             MT  VARZEA GRANDE
#
#                                                   Revenda  \
# 0       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 1       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 2       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 3               LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA
# ...

# %%
data2017_1 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2017\\ca-2017-01.csv",on_bad_lines='skip', sep=';')
DF2017_1 = pd.DataFrame(data2017_1)
data2017_2 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2017\\ca-2017-02.csv",on_bad_lines='skip',  sep=';')
DF2017_2 = pd.DataFrame(data2017_2)

DF2017 = pd.concat([DF2017_1,DF2017_2], axis = 0)

print(DF2017)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  SE             SP  GUARULHOS
# 1                  SE             SP  GUARULHOS
# 2                  SE             SP  GUARULHOS
# 3                  SE             SP  GUARULHOS
# 4                  SE             SP  GUARULHOS
# ...               ...            ...        ...
# 300942              S             RS     VIAMAO
# 300943              S             RS     VIAMAO
# 300944              S             RS     VIAMAO
# 300945             NE             BA  BARREIRAS
# 300946             NE             BA  BARREIRAS
#
#                                      Revenda      CNPJ da Revenda  \
# 0                   AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 1                   AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 2                   AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 3                   AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# ...

# %%
data2018_1 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2018\\ca-2018-01.csv",on_bad_lines='skip', sep=';')
DF2018_1 = pd.DataFrame(data2018_1)
data2018_2 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2018\\ca-2018-02.csv",on_bad_lines='skip',  sep=';')
DF2018_2 = pd.DataFrame(data2018_2)

DF2018 = pd.concat([DF2018_1,DF2018_2], axis = 0)

print(DF2018)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  NE             BA   SALVADOR
# 1                  NE             BA   SALVADOR
# 2                  NE             BA   SALVADOR
# 3                  NE             BA   SALVADOR
# 4                   S             RS     CANOAS
# ...               ...            ...        ...
# 493164             SE             SP     LORENA
# 493165             SE             SP     LORENA
# 493166              N             RR  BOA VISTA
# 493167              N             RR  BOA VISTA
# 493168              N             RR  BOA VISTA
#
#                                             Revenda      CNPJ da Revenda  \
# 0                      PETROBRAS DISTRIBUIDORA S.A.   34.274.233/0015-08
# 1                      PETROBRAS DISTRIBUIDORA S.A.   34.274.233/0015-08
# 2                      PETROBRAS DISTRIBUIDORA S.A.   34.274.233/0015-08
# 3                      PETROBRAS DISTRIBUIDORA S.A.   34.274.233/0015-08
# ...

# %%
data2019_1 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2019\\ca-2019-01.csv",on_bad_lines='skip', sep=';')
DF2019_1 = pd.DataFrame(data2019_1)
data2019_2 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2019\\ca-2019-02.csv",on_bad_lines='skip',  sep=';')
DF2019_2 = pd.DataFrame(data2019_2)

DF2019 = pd.concat([DF2019_1,DF2019_2], axis = 0)

print(DF2019)
# Out:
#        Regiao - Sigla Estado - Sigla                 Municipio  \
# 0                  SE             SP                 GUARULHOS
# 1                  SE             SP                 GUARULHOS
# 2                  SE             SP                 GUARULHOS
# 3                  SE             SP                 GUARULHOS
# 4                   S             RS                    CANOAS
# ...               ...            ...                       ...
# 507294             SE             SP                    LORENA
# 507295             SE             MG  SAO SEBASTIAO DO PARAISO
# 507296             SE             MG  SAO SEBASTIAO DO PARAISO
# 507297             SE             MG  SAO SEBASTIAO DO PARAISO
# 507298             SE             MG  SAO SEBASTIAO DO PARAISO
#
#                                             Revenda      CNPJ da Revenda  \
# 0                          AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# ...

# %%
data2020_1 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2020\\ca-2020-01.csv",on_bad_lines='skip', sep=';')
DF2020_1 = pd.DataFrame(data2020_1)
data2020_2 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\2020\\ca-2020-02.csv",on_bad_lines='skip',  sep=';')
DF2020_2 = pd.DataFrame(data2020_2)

DF2020 = pd.concat([DF2020_1,DF2020_2], axis = 0)

print(DF2020)
# Out:
#        Regiao - Sigla Estado - Sigla       Municipio  \
# 0                  SE             SP       GUARULHOS
# 1                  SE             SP       GUARULHOS
# 2                  SE             SP       GUARULHOS
# 3                  SE             SP       GUARULHOS
# 4                  NE             BA        SALVADOR
# ...               ...            ...             ...
# 222632             SE             RJ  RIO DE JANEIRO
# 222633             SE             RJ  RIO DE JANEIRO
# 222634             SE             RJ  RIO DE JANEIRO
# 222635             SE             RJ  RIO DE JANEIRO
# 222636             SE             RJ  RIO DE JANEIRO
#
#                                    Revenda      CNPJ da Revenda  \
# 0                 AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 1                 AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 2                 AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 3                 AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# ...

# %%
data2021_1 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\Planilhas\\ca-2021-01.csv",encoding='ISO-8859-1',on_bad_lines='skip', sep=';')
DF2021_1 = pd.DataFrame(data2021_1)
data2021_2 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\Planilhas\\ca-2021-02.csv",encoding='ISO-8859-1',on_bad_lines='skip',  sep=';')
DF2021_2 = pd.DataFrame(data2021_2)

DF2021 = pd.concat([DF2021_1,DF2021_2], axis = 0)

print(DF2021)
# Out:
#        ï»¿Regiao - Sigla Estado - Sigla     Municipio  \
# 0                      S             RS  SAO LEOPOLDO
# 1                      S             RS  SAO LEOPOLDO
# 2                      S             RS  SAO LEOPOLDO
# 3                      S             RS  SAO LEOPOLDO
# 4                      S             RS  SAO LEOPOLDO
# ...                  ...            ...           ...
# 472851               NaN             BA        JEQUIE
# 472852               NaN             MG     ITUIUTABA
# 472853               NaN             MG     ITUIUTABA
# 472854               NaN             MG     ITUIUTABA
# 472855               NaN             MG     ITUIUTABA
#
#                                            Revenda      CNPJ da Revenda  \
# 0            POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 1            POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 2            POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# ...

# %%
data2022_1 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\Planilhas\\ca-2022-01.csv",on_bad_lines='skip', sep=';')
DF2022_1 = pd.DataFrame(data2022_1)
data2022_2 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\Planilhas\\ca-2022-02.csv",on_bad_lines='skip',  sep=';')
DF2022_2 = pd.DataFrame(data2022_2)

DF2022 = pd.concat([DF2022_1,DF2022_2], axis = 0)

print(DF2022)
# Out:
#        Regiao - Sigla Estado - Sigla   Municipio  \
# 0                   N             AC  RIO BRANCO
# 1                   N             AC  RIO BRANCO
# 2                   N             AC  RIO BRANCO
# 3                   N             AC  RIO BRANCO
# 4                   N             AC  RIO BRANCO
# ...               ...            ...         ...
# 378073              S             SC    BLUMENAU
# 378074              S             SC    BLUMENAU
# 378075              S             SC    BLUMENAU
# 378076              S             SC    BLUMENAU
# 378077              S             SC    BLUMENAU
#
#                                Revenda      CNPJ da Revenda  \
# 0            AUTO POSTO AMAPA - EIRELI   00.529.581/0001-53
# 1            AUTO POSTO AMAPA - EIRELI   00.529.581/0001-53
# 2            AUTO POSTO AMAPA - EIRELI   00.529.581/0001-53
# 3            AUTO POSTO AMAPA - EIRELI   00.529.581/0001-53
# 4            AUTO POSTO AMAPA - EIRELI   00.529.581/0001-53
# ...

# %%
data2023_1 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\Planilhas\\ca-2023-01.csv",on_bad_lines='skip', sep=';')
DF2023_1 = pd.DataFrame(data2023_1)
data2023_2 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\Planilhas\\ca-2023-02.csv",on_bad_lines='skip',  sep=';')
DF2023_2 = pd.DataFrame(data2023_2)

DF2023 = pd.concat([DF2023_1,DF2023_2], axis = 0)

print(DF2023)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  SE             SP   SOROCABA
# 1                  SE             SP   SOROCABA
# 2                  SE             SP   SOROCABA
# 3                  NE             AL  ARAPIRACA
# 4                  NE             AL  ARAPIRACA
# ...               ...            ...        ...
# 472419              N             AP    SANTANA
# 472420              N             AP    SANTANA
# 472421             NE             PI   PARNAIBA
# 472422             NE             PI   PARNAIBA
# 472423             NE             PI   PARNAIBA
#
#                                                   Revenda  \
# 0       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 1       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 2       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 3       COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...
# 4       COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...
# ...

# %%
data2024_1 = pd.read_csv("C:\\Users\\User\\Desktop\\PI\\DADOS\\Planilhas\\ca-2024-01.csv",on_bad_lines='skip', sep=';')
DF2024 = pd.DataFrame(data2024_1)

print(DF2024)
# Out:
#        Regiao - Sigla Estado - Sigla    Municipio  \
# 0                  NE             AL    ARAPIRACA
# 1                  NE             AL    ARAPIRACA
# 2                  NE             AL    ARAPIRACA
# 3                  NE             AL    ARAPIRACA
# 4                  NE             AL    ARAPIRACA
# ...               ...            ...          ...
# 477149              S             PR  CAMPO LARGO
# 477150             NE             MA       CAXIAS
# 477151             NE             MA       CAXIAS
# 477152             NE             MA       CAXIAS
# 477153             NE             MA       CAXIAS
#
#                                                   Revenda  \
# 0       COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...
# 1       COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...
# 2       COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...
# 3       COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...
# 4                           AUTO POSTO SAO FRANCISCO LTDA
# ...

# %%
DF = pd.concat([DF2004,DF2005,DF2006,DF2007,DF2008,DF2009,DF2010,DF2011,DF2012,DF2013,DF2014,DF2015,DF2016,DF2017,DF2018,DF2019,DF2020,DF2021,DF2022,DF2023,DF2024], axis = 0)

# %%
print(DF)
# Out:
#        Regiao - Sigla Estado - Sigla    Municipio  \
# 0                  SE             SP    GUARULHOS
# 1                  SE             SP    GUARULHOS
# 2                  SE             SP    GUARULHOS
# 3                  SE             SP     SOROCABA
# 4                  SE             SP     SOROCABA
# ...               ...            ...          ...
# 477149              S             PR  CAMPO LARGO
# 477150             NE             MA       CAXIAS
# 477151             NE             MA       CAXIAS
# 477152             NE             MA       CAXIAS
# 477153             NE             MA       CAXIAS
#
#                                                   Revenda  \
# 0                                AUTO POSTO SAKAMOTO LTDA
# 1                                AUTO POSTO SAKAMOTO LTDA
# 2                                AUTO POSTO SAKAMOTO LTDA
# 3       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 4       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# ...

# %%
print(DF.columns)
# Out:
# Index(['Regiao - Sigla', 'Estado - Sigla', 'Municipio', 'Revenda',
#        'CNPJ da Revenda', 'Nome da Rua', 'Numero Rua', 'Complemento', 'Bairro',
#        'Cep', 'Produto', 'Data da Coleta', 'Valor de Venda', 'Valor de Compra',
#        'Unidade de Medida', 'Bandeira', 'ï»¿Regiao - Sigla'],
#       dtype='object')

# %%
#DF.to_csv('nome_do_arquivo.csv', index=False)

# %%
DF.drop(columns="ï»¿Regiao - Sigla")

# %%
#DF.to_csv('DADOS.csv', index=False)
